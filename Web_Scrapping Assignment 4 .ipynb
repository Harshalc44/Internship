# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
video_name  = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')

# %%
artist = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')

# %%
upload_date = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')

# %%
views = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')

# %%
Video_name = []
Artist = []
Uploaded_date = []
Views = []

# %%
video_name  = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for i in video_name:
    video=i.text
    Video_name.append(video)

# %%
artist = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for i in artist:
    art=i.text
    Artist.append(art)
    

upload_date = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for i in upload_date:
    up=i.text
    Uploaded_date.append(up)
    

views = driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for i in  views:
    view=i.text
    Views.append(view)

# %%
df = pd.DataFrame({'Video_Name':Video_name,'Artist':Artist,'Uploaded_date':Uploaded_date,'Views':Views})
df
# Out:
#                                          Video_Name  \
# 0                             "Baby Shark Dance"[6]
# 1                                    "Despacito"[9]
# 2                        "Johny Johny Yes Papa"[17]
# 3                                   "Bath Song"[18]
# 4                                "Shape of You"[19]
# 5                               "See You Again"[22]
# 6                           "Wheels on the Bus"[27]
# 7                 "Phonics Song with Two Words"[28]
# 8                                 "Uptown Funk"[29]
# 9   "Learning Colors – Colorful Eggs on a Farm"[30]
# 10                              "Gangnam Style"[31]
# 11   "Masha and the Bear – Recipe for Disaster"[36]
# 12                             "Dame Tu Cosita"[37]
# 13                                     "Axel F"[38]
# 14                                      "Sugar"[39]
# 15                             "Counting Stars"[40]
# 16                                       "Roar"[41]
# ...

# %% [markdown]
# Q2

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.bcci.tv/')

# %%
series = driver.find_elements(By.CLASS_NAME,"match-tournament-name ng-binding")

# %%
location = driver.find_elements(By.CLASS_NAME,"match-place ng-scope")

# %%
date = driver.find_elements(By.CLASS_NAME,"match-dates ng-binding")

# %%
time = driver.find_elements(By.CLASS_NAME,"match-time no-margin ng-binding")

# %%
Series = []
Location = []
Date = []
Time = []

# %%
series = driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
for i in series:
    ser=i.text
    Series.append(ser)


location = driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')
for i in location:
    loc= i.text
    Location.append(loc)
    

date = driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
for i in date:
    da = i.text
    Date.append(da)
    
    
time = driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in time:
    ti = i.text
    Time.append(ti)

# %%
print(len(Series),len(Location),len(Date),len(Time))
# Out:
# 211 211 211 211

# %%
df = pd.DataFrame({'Series':Series,"Place":Location,'Date':Date,'Time':Time})
df
# Out:
#                           Series  \
# 0        ICC MENS WORLD CUP 2023
# 1        ICC MENS WORLD CUP 2023
# 2        ICC MENS WORLD CUP 2023
# 3        ICC MENS WORLD CUP 2023
# 4        ICC MENS WORLD CUP 2023
# ..                           ...
# 206                ASIA CUP 2022
# 207                ASIA CUP 2022
# 208  NEW ZEALAND A TOUR OF INDIA
# 209                ASIA CUP 2022
# 210                ASIA CUP 2022
#
#                                                  Place               Date  \
# 0                     Narendra Modi Stadium, Ahmedabad   14 OCTOBER, 2023
# 1        Maharashtra Cricket Association Stadium, Pune   19 OCTOBER, 2023
# 2    Himachal Pradesh Cricket Association Stadium, ...   22 OCTOBER, 2023
# 3    Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   29 OCTOBER, 2023
# 4                             Wankhede Stadium, Mumbai   2 NOVEMBER, 2023
# ..                                                 ...                ...
# ...

# %% [markdown]
# # Q3

# %%
driver = webdriver.Chrome()

# %%
driver.get('http://statisticstimes.com/')

# %%
rank = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[1]')

# %%
state = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[2]')

# %%
gsdp_1819 = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]')

# %%
gsdp_1920 = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[3]')

# %%
share = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[5]')

# %%
Gdp = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[6]')

# %%
Rank = []
State = []
Gsdp_1819 = []
Gsdp_1920 = []
Share = []
GDP = []

# %%
rank = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[1]')
for i in rank:
    ra=i.text
    Rank.append(ra)
    

state = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[2]')
for i in state:
    st=i.text
    State.append(st)

    
    
gsdp_1819 = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]')
for i in gsdp_1819:
    gsdp= i.text
    Gsdp_1819.append(gsdp)
    
    

gsdp_1920 = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[3]')
for i in gsdp_1920:
    gs=i.text
    Gsdp_1920.append(gs)
    


share = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[5]')
for i in share:
    sh = i.text
    Share.append(sh)
    
    

Gdp = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[6]')
for i in Gdp:
    gd =i.text
    GDP.append(gd)

# %%
print(len(Rank),len(State),len(Gsdp_1819),len(Gsdp_1920),len(Share),len(GDP))
# Out:
# 66 66 66 66 66 66

# %%
df = pd.DataFrame({'Rank':Rank,'State':State,'GSDP(18-19)':Gsdp_1819,'GSDP(19-20)':Gsdp_1920,'Share':Share,'GDP':GDP})
df
# Out:
#    Rank                      State GSDP(18-19) GSDP(19-20)   Share      GDP
# 0     1                Maharashtra   2,632,792           -  13.94%  399.921
# 1     2                 Tamil Nadu   1,630,208   1,845,853   8.63%  247.629
# 2     3              Uttar Pradesh   1,584,764   1,687,818   8.39%  240.726
# 3     4                    Gujarat   1,502,899           -   7.96%  228.290
# 4     5                  Karnataka   1,493,127   1,631,977   7.91%  226.806
# ..  ...                        ...         ...         ...     ...      ...
# 61   29                     Sikkim      25,141      28,391   0.15%   17,060
# 62   30                   Nagaland      24,534           -   0.15%        -
# 63   31          Arunachal Pradesh      22,488           -   0.13%        -
# 64   32                    Mizoram      20,947      24,424   0.13%   17,797
# 65   33  Andaman & Nicobar Islands           -           -       -        -
#
# [66 rows x 6 columns]

# %% [markdown]
# # Q4

# %% [markdown]
# # Q5

# %% [markdown]
# # Q6

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
name = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')

# %%
author = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')

# %%
volumns = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')

# %%
publisher = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')

# %%
genre = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')

# %%
Name = []
Author = []
Volumns = []
Publisher = []
Genre = []

# %%
name = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in name:
    na=i.text
    Name.append(na)
    
    
author = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author:
    aut= i.text
    Author.append(aut)
    
    
volumns = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in volumns:
    vol = i.text
    Volumns.append(vol)
    
    
publisher = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in publisher:
    pub = i.text
    Publisher.append(pub)
    
    
genre = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in genre:
    gen = i.text
    Genre.append(gen)

# %%
print(len(Name),len(Author),len(Volumns),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
df = pd.DataFrame({'Book Name':Name,'Author Name':Author,'Volumns sold':Volumns,'Publisher':Publisher,'Genre':Genre})
df
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumns sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q7

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
name = driver.find_elements(By.CLASS_NAME,"lister-item-header")

# %%
year = driver.find_elements(By.CLASS_NAME,'lister-item-year text-muted unbold')

# %%
genre = driver.find_elements(By.CLASS_NAME,"genre")

# %%
time = driver.find_elements(By.CLASS_NAME,'runtime')

# %%
rating = driver.find_elements(By.CLASS_NAME,'ipl-rating-star small')

# %%
votes = driver.find_elements(By.CLASS_NAME,"nv")

# %%
Name = []
Year = []
Genre = []
Time = []
Rating = []
Votes = []

# %%
name = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')
for i in name:
    na = i.text
    Name.append(na)
    
    
year = driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')
for i in year:
    ye = i.text
    Year.append(ye)
    
    
genre = driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in genre:
    gen = i.text
    Genre.append(gen)
    
time = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in time:
    ti = i.text
    Time.append(ti)
    
    
rating = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in rating:
    rat = i.text
    Rating.append(rat)

    
votes = driver.find_elements(By.XPATH,'//span[@name="nv"]')
for i in votes:
    vot = i.text
    Votes.append(vot)

# %%
print(len(Name),len(Year),len(Genre),len(Time),len(Rating),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
df = pd.DataFrame({'Name':Name,'Year Span':Year,'Genre':Genre,'Run time':Time,'Ratings':Rating,'Votes':Votes})
df
# Out:
#                                               Name    Year Span  \
# 0                   1. Game of Thrones (2011–2019)  (2011–2019)
# 1                   2. Stranger Things (2016–2025)  (2016–2025)
# 2                  3. The Walking Dead (2010–2022)  (2010–2022)
# 3                    4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                           5. The 100 (2014–2020)  (2014–2020)
# ..                                             ...          ...
# 95                           96. Reign (2013–2017)  (2013–2017)
# 96  97. A Series of Unfortunate Events (2017–2019)  (2017–2019)
# 97                     98. Criminal Minds (2005– )     (2005– )
# 98           99. Scream: The TV Series (2015–2019)  (2015–2019)
# 99          100. The Haunting of Hill House (2018)       (2018)
#
#                        Genre Run time Ratings      Votes
# 0   Action, Adventure, Drama   57 min     9.2  2,212,240
# 1     Drama, Fantasy, Horror   51 min     8.7  1,282,254
# ...

# %% [markdown]
# # Q8

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
name = driver.find_elements(By.CLASS_NAME,"link-hover link text-xl font-semibold")

# %%
d_type = driver.find_elements(By.CLASS_NAME,'truncate')

# %%
task = driver.find_elements(By.CLASS_NAME,"truncate")

# %%
a_type = driver.find_elements(By.XPATH,'//table[@class="col-span-full my-2 table sm:col-start-2"]/tbody/tr/td[2]')

# %%
instances = driver.find_elements(By.CLASS_NAME,"truncate")

# %%
attribute = driver.find_elements(By.CLASS_NAME,"truncate")

# %%
year = driver.find_elements(By.XPATH,'//table[@class="col-span-full my-2 table sm:col-start-2"]/tbody/tr/td[3]')

# %%
Name = []
D_type = []
Task = []
A_type = []
Instances = []
Attributes = []
Year = []

# %%
name = driver.find_elements(By.XPATH,//'a[@class="link-hover link text-xl font-semibold"]')
for i in name:
    na =  i.text
    Name.append(na)
    

d_type = driver.find_elements(By.XPATH,'')
